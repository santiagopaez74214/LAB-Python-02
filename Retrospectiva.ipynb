# %% [markdown]
# Retrospectiva
# 1. ¿Cuál fue el tiempo total invertido en el laboratorio por cada uno de ustedes? (Horas/Hombre)
# El tiempo total invertido en el laboratorio fue de aproximadamente 4 horas por persona (4 horas/hombre).
# 2. ¿Cuál es el estado actual del laboratorio? ¿Por qué?
# El laboratorio se encuentra completo, ya que se realizaron en su totalidad todos los ejercicios solicitados y se probaron con los resultados esperados.
# 3. ¿Cuál consideran fue el mayor logro? ¿Por qué?
# El mayor logro fue realizar en su totalidad los ejercicios incluyendo funciones como lambda, map, reduce, sorted y filter. Además de la aplicación del algoritmo de Minimax
# 4. ¿Cuál consideran que fue el mayor problema técnico? ¿Qué hicieron para resolverlo?
# El mayor problema técnico fue entender la aplicación del Minimax y usar nuestros conocimientos en Python para resolverlo, para esto buscamos en internet para entender mejor el tema, y la presentación vista en clase del día viernes, por otro lado la estructura de las funciones de los otros ejercicios para su aplicación sobre listas y diccionarios
# 5. ¿Qué hicieron bien como equipo? ¿Qué se comprometen a hacer para mejorar los resultados?
# Dividirnos bien las labores y trabajar fuertemente en clase para no llevarnos mucho trabajo a casa, además de preguntar en caso de cualquier duda, y nos comprometemos a seguir constante en la entrega y aprendizaje durante este tercio con Python
# 6. ¿Qué referencias usaron? ¿Cuál fue la más útil? Incluyan citas con estándares adecuados.
#     * Python Software Foundation.Python Documentation. Disponible en: https://docs.python.org/3/
#     * Consultas de apoyo en herramientas de inteligencia artificial para aclarar dudas conceptuales y revisar soluciones.
#     * Explicaciones del profesor durante la clase.
#     * Presentaciones y material teórico suministrado en las sesiones presenciales.
